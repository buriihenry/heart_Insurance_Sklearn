# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
heart= pd.read_csv('heart.csv')
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#For the ‘heart’ data frame, rename the column ‘target’ to’ heart disease’.
heart.rename(columns={'target': 'heart disease'}, inplace=True)
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  heart disease
# 0   0     1              1
# 1   0     2              1
# 2   0     2              1
# 3   0     2              1
# 4   0     2              1

# %%
insurance = pd.read_csv('insurance.csv')
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import pandas_profiling as pp

# %%
#pp.ProfileReport(insurance)

# %%
X = insurance.iloc[:,:-1].values
Y = insurance.iloc[:,5].values

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
X[:, 1] = labelencoder.fit_transform(X[:, 1])
X
# Out:
# array([[19, 0, 27.9, 0, 'yes', 'southwest'],
#        [18, 1, 33.77, 1, 'no', 'southeast'],
#        [28, 1, 33.0, 3, 'no', 'southeast'],
#        ...,
#        [18, 0, 36.85, 0, 'no', 'southeast'],
#        [21, 0, 25.8, 0, 'no', 'southwest'],
#        [61, 0, 29.07, 0, 'yes', 'northwest']], dtype=object)

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
gender_cat = pd.get_dummies(insurance, columns=['sex', 'smoker', 'region'])

# %%
gender_cat
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
#Explore each data frame using at least 2 data exploratory tools of your choosing in pandas
import seaborn as sns

# %%
heart.dtypes
# Out:
# age                int64
# sex                int64
# cp                 int64
# trestbps           int64
# chol               int64
# fbs                int64
# restecg            int64
# thalach            int64
# exang              int64
# oldpeak          float64
# slope              int64
# ca                 int64
# thal               int64
# heart disease      int64
# dtype: object

# %%
sns.pairplot(heart,vars = ['age','oldpeak'], hue="heart disease")

# %%
insurance.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            303 non-null    int64
#  1   sex            303 non-null    int64
#  2   cp             303 non-null    int64
#  3   trestbps       303 non-null    int64
#  4   chol           303 non-null    int64
#  5   fbs            303 non-null    int64
#  6   restecg        303 non-null    int64
#  7   thalach        303 non-null    int64
#  8   exang          303 non-null    int64
#  9   oldpeak        303 non-null    float64
#  10  slope          303 non-null    int64
#  11  ca             303 non-null    int64
#  12  thal           303 non-null    int64
#  13  heart disease  303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#df_all = pd.concat(heart, insurance, how='outer',
                  #left_on='age', right_on='region')
#df_all = df_all.drop('region', 1) # drop duplicate info
#df_all.head()

# %%
#Using Concat Method will not yeild the results wanted.
df_all = pd.concat([heart, insurance], axis=1)
df_all= df_all.reindex(heart.index)

# %%
df_all.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  3.0     145.0  233.0  1.0      0.0    150.0    0.0      2.3
# 1  37.0  1.0  2.0     130.0  250.0  0.0      1.0    187.0    0.0      3.5
# 2  41.0  0.0  1.0     130.0  204.0  0.0      0.0    172.0    0.0      1.4
# 3  56.0  1.0  1.0     120.0  236.0  0.0      1.0    178.0    0.0      0.8
# 4  57.0  0.0  0.0     120.0  354.0  0.0      1.0    163.0    1.0      0.6
#
#    ...   ca  thal  heart disease  age     sex     bmi  children  smoker  \
# 0  ...  0.0   1.0            1.0   19  female  27.900         0     yes
# 1  ...  0.0   2.0            1.0   18    male  33.770         1      no
# 2  ...  0.0   2.0            1.0   28    male  33.000         3      no
# 3  ...  0.0   2.0            1.0   33    male  22.705         0      no
# 4  ...  0.0   2.0            1.0   32    male  28.880         0      no
#
#       region      charges
# 0  southwest  16884.92400
# 1  southeast   1725.55230
# ...

# %%
#question 5 Use Merge function to combine two dataframes

df_all = pd.merge(heart, insurance, left_on='age', right_on='age')
df_all
# Out:
#       age  sex_x  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63      1   3       145   233    1        0      150      0      2.3
# 1      63      1   3       145   233    1        0      150      0      2.3
# 2      63      1   3       145   233    1        0      150      0      2.3
# 3      63      1   3       145   233    1        0      150      0      2.3
# 4      63      1   3       145   233    1        0      150      0      2.3
# ...   ...    ...  ..       ...   ...  ...      ...      ...    ...      ...
# 6880   38      1   3       120   231    0        1      182      1      3.8
# 6881   38      1   3       120   231    0        1      182      1      3.8
# 6882   38      1   3       120   231    0        1      182      1      3.8
# 6883   38      1   3       120   231    0        1      182      1      3.8
# 6884   38      1   3       120   231    0        1      182      1      3.8
#
# ...

# %%
df_all.columns
# Out:
# Index(['age', 'sex_x', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heart disease', 'sex_y',
#        'bmi', 'children', 'smoker', 'region', 'charges'],
#       dtype='object')

# %%
df_all['age']
# Out:
# 0       63
# 1       63
# 2       63
# 3       63
# 4       63
#         ..
# 6880    38
# 6881    38
# 6882    38
# 6883    38
# 6884    38
# Name: age, Length: 6885, dtype: int64

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Question 6 
#Age Distribution in df_all
import plotly.express as px
fig = px.histogram(df_all, x="age",
                   title="Age Distribution",
                   width=600, height=300)
fig.show()
# Out:
# <div>                            <div id="598a77ba-0096-4641-9b56-f70cae470939" class="plotly-graph-div" style="height:300px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("598a77ba-0096-4641-9b56-f70cae470939")) {                    Plotly.newPlot(                        "598a77ba-0096-4641-9b56-f70cae470939",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "age=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63
# ...

# %%
#Question 6
#Age distribution in heart df
import plotly.express as px
fig = px.histogram(heart, x="age",
                   title="Age Distribution",
                   width=600, height=300)
fig.show()
# Out:
# <div>                            <div id="c2eb8500-e9ee-4855-8af1-2f028ac73541" class="plotly-graph-div" style="height:300px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2eb8500-e9ee-4855-8af1-2f028ac73541")) {                    Plotly.newPlot(                        "c2eb8500-e9ee-4855-8af1-2f028ac73541",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "age=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [63, 37, 41, 56, 57, 57, 56, 44, 52, 57, 54, 48, 49, 64, 58, 50, 58, 66, 43, 69, 59, 44, 42, 61, 40, 71, 59, 51, 65, 53, 41, 65, 44, 54, 51, 46, 54, 54, 65, 65, 51, 48, 45, 53, 39, 52, 44, 47, 53, 53, 51, 66, 62, 44
# ...

# %%
df_all.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       age  sex_x  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63      1   3       145   233    1        0      150      0      2.3
# 1      63      1   3       145   233    1        0      150      0      2.3
# 2      63      1   3       145   233    1        0      150      0      2.3
# 3      63      1   3       145   233    1        0      150      0      2.3
# 4      63      1   3       145   233    1        0      150      0      2.3
# ...   ...    ...  ..       ...   ...  ...      ...      ...    ...      ...
# 6880   38      1   3       120   231    0        1      182      1      3.8
# 6881   38      1   3       120   231    0        1      182      1      3.8
# 6882   38      1   3       120   231    0        1      182      1      3.8
# 6883   38      1   3       120   231    0        1      182      1      3.8
# 6884   38      1   3       120   231    0        1      182      1      3.8
#
# ...

# %%
df_all.isna().sum()
# Out:
# age              0
# sex_x            0
# cp               0
# trestbps         0
# chol             0
# fbs              0
# restecg          0
# thalach          0
# exang            0
# oldpeak          0
# slope            0
# ca               0
# thal             0
# heart disease    0
# sex_y            0
# bmi              0
# children         0
# smoker           0
# region           0
# charges          0
# dtype: int64

# %%
numerical_continuous = df_all.dtypes[df_all.dtypes != "object"].index
numerical_continuous
# Out:
# Index(['age', 'sex_x', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heart disease', 'bmi',
#        'children', 'charges'],
#       dtype='object')

# %%
df_all.select_dtypes('number').columns
# Out:
# Index(['age', 'sex_x', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heart disease', 'bmi',
#        'children', 'charges'],
#       dtype='object')

# %%
#Question 8
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_continuous = df_all.select_dtypes(include=numerics)
numerical_continuous
# Out:
#       age  sex_x  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      63      1   3       145   233    1        0      150      0      2.3
# 1      63      1   3       145   233    1        0      150      0      2.3
# 2      63      1   3       145   233    1        0      150      0      2.3
# 3      63      1   3       145   233    1        0      150      0      2.3
# 4      63      1   3       145   233    1        0      150      0      2.3
# ...   ...    ...  ..       ...   ...  ...      ...      ...    ...      ...
# 6880   38      1   3       120   231    0        1      182      1      3.8
# 6881   38      1   3       120   231    0        1      182      1      3.8
# 6882   38      1   3       120   231    0        1      182      1      3.8
# 6883   38      1   3       120   231    0        1      182      1      3.8
# 6884   38      1   3       120   231    0        1      182      1      3.8
#
# ...

# %%
numerical_discrete= df_all.select_dtypes(exclude=['int', 'float']).columns
numerical_discrete
# Out:
# Index(['age', 'sex_x', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'slope', 'ca', 'thal', 'heart disease', 'sex_y', 'children',
#        'smoker', 'region'],
#       dtype='object')

# %%
#Question 10 
#check if there are outliers 
plt.figure(figsize=(13,7))
sns.boxplot(df_all.charges)
# Out:
# <AxesSubplot:xlabel='charges'>

# %%
#treating Outliers using Z-Score
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df_all.charges))
print(z)
# Out:
# [0.16624656 0.22421628 2.60612253 ... 0.75421733 0.83045896 0.78850759]

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([1576, 1605, 1634, 1663, 1692, 1721, 1750, 1779, 1808, 1837, 1866,
#        1895, 1924, 1940, 1968, 1996, 2024, 2052, 2080, 2108, 2136, 2164,
#        2192, 2220, 2248, 2276, 2304, 2332, 2360, 5468, 5497, 5526, 5555,
#        5584, 5613, 5642, 5671, 6579, 6602, 6625, 6648, 6671, 6694, 6717,
#        6740, 6763, 6786, 6809], dtype=int64),)

# %%
import numpy as np

def outliers_z_score(ys):
    threshold = 3

    mean_y = np.mean(ys)
    stdev_y = np.std(ys)
    z_scores = [(y - mean_y) / stdev_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)

# %%
#df_all = df_all.charges[(z < 3).all(axis=0)]
#df_all.charges.loc[df_all.charges['z'].abs()<=3]
#outliers_z_score (df_all.charges)
#df_all = df_all.loc[df_all.charges['z'].abs()<=3]
#sns.boxplot(df_all.charges)

# %%
plt.figure(figsize=(13,7))
sns.boxplot(df_all.charges)
# Out:
# <AxesSubplot:xlabel='charges'>

# %%
#Method 2
import numpy as np

def outliers_z_score(ys):
    threshold = 3

    mean_y = np.mean(ys)
    stdev_y = np.std(ys)
    z_scores = [(y - mean_y) / stdev_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)

# %%
outliers_z_score(df_all.charges)
# Out:
# (array([1576, 1605, 1634, 1663, 1692, 1721, 1750, 1779, 1808, 1837, 1866,
#         1895, 1924, 1940, 1968, 1996, 2024, 2052, 2080, 2108, 2136, 2164,
#         2192, 2220, 2248, 2276, 2304, 2332, 2360, 5468, 5497, 5526, 5555,
#         5584, 5613, 5642, 5671, 6579, 6602, 6625, 6648, 6671, 6694, 6717,
#         6740, 6763, 6786, 6809], dtype=int64),)

# %%
df_all.dtypes

# %%
df_all

# %%
sns.pairplot(heart,vars = ['age'], hue="heart disease")

# %%
sns.pairplot(df_all,vars = ['age'], hue="heart disease")

# %%
df_all.age

# %%
heart_disease= pd.read_csv('heart.csv')
heart_disease.head()

# %%
heart.info()

# %%
X = heart_disease.drop('target',axis =1)
y = heart_disease['target']

# %%
X.head()

# %%
y.head()

# %%
#check if the data is balanced
y.head(),y.value_counts()

# %%
#Splitting the data into training and test sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y)

X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# #Choose the model and hyperparameters

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)

# %%
clf.get_params()

# %%
#fit the model
clf.fit(X_train,y_train)

# %%
#make perictions
y_preds = clf.predict(X_test)
y_preds

# %%
#Evaluate the Model
clf.score(X_train,y_train)

# %%
clf.score(X_test, y_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(classification_report(y_test, y_preds))

# %%
conf_mat = confusion_matrix(y_test, y_preds)
conf_mat

# %%
accuracy_score(y_test, y_preds)

# %%
#Hyperparameter Tuning
np.random.seed(42)
for i in range(10,100,10):
    print(f"Trying model with {i} estimators...")
    model = RandomForestClassifier(n_estimators=1).fit(X_train, y_train)
    print(f"Model accuracy on test set: {model.score(X_test, y_test) * 100}%")
    print("")
